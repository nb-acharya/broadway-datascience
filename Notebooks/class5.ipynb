# %%
import pandas as pd
import numpy as np
print("import done")
# Out:
# import done

# %%
df = pd.read_csv("../Dataset/Employees.csv")
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  6/17/2003
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4            104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# ..           ...        ...       ...       ...           ...        ...
# 106          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
# 107          203      Susan    Mavris   SMAVRIS  515.123.7777   6/7/2002
# 108          204    Hermann      Baer     HBAER  515.123.8888   6/7/2002
# 109          205    Shelley   Higgins  SHIGGINS  515.123.8080   6/7/2002
# 110          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
df.dropna(axis = 1, how='all', inplace=True)

# %%
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  6/17/2003
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4            104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# ..           ...        ...       ...       ...           ...        ...
# 106          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
# 107          203      Susan    Mavris   SMAVRIS  515.123.7777   6/7/2002
# 108          204    Hermann      Baer     HBAER  515.123.8888   6/7/2002
# 109          205    Shelley   Higgins  SHIGGINS  515.123.8080   6/7/2002
# 110          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
df = pd.read_csv("../Dataset/Fraud Detection Dataset.csv")
df
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# ...

# %%
df['Time_of_Transaction'].unique()
# Out:
# array([16., 13., nan, 15., 19.,  2.,  3., 20.,  0., 12., 21., 14.,  7.,
#         4., 17., 10.,  5.,  8., 11., 18.,  1., 22.,  9.,  6., 23.])

# %%
df['Device_Used'].unique()
# Out:
# <StringArray>
# ['Tablet', 'Mobile', 'Desktop', nan, 'Unknown Device']
# Length: 5, dtype: str

# %%
df['Device_Used'].mode()
# Out:
# 0    Desktop
# Name: Device_Used, dtype: str

# %%
df['Location'].unique()
# Out:
# <StringArray>
# ['San Francisco',      'New York',             nan,       'Chicago',
#         'Boston',       'Houston',         'Miami',   'Los Angeles',
#        'Seattle']
# Length: 9, dtype: str

# %%
df['Payment_Method'].unique()
# Out:
# <StringArray>
# ['Debit Card', 'Credit Card', nan, 'UPI', 'Net Banking', 'Invalid Method']
# Length: 6, dtype: str

# %%
# later in machine learning we will learn how to fill the data using machine learning algorithms, for now, just use unknown if you dont know the data,

# %%
# filling data in missing values is called imputation, done by data engineer eh?

# %%
df['Time_of_Transaction'] = df['Time_of_Transaction'].fillna(0)

# %%
df['Device_Used']= df['Device_Used'].fillna('Unknown Device')

# %%
df['Location'] = df['Location'].fillna('Unknown Location')

# %%
df['Payment_Method']= df['Payment_Method'].fillna('Unknown Method')

# %%
df.isnull().sum()
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                  2520
# Transaction_Type                       0
# Time_of_Transaction                    0
# Device_Used                            0
# Location                               0
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                         0
# Fraudulent                             0
# dtype: int64

# %%
df['Time_of_Transaction'] = df['Time_of_Transaction'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  str
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                48480 non-null  float64
#  3   Transaction_Type                  51000 non-null  str
#  4   Time_of_Transaction               51000 non-null  int64
#  5   Device_Used                       51000 non-null  str
#  6   Location                          51000 non-null  str
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    51000 non-null  str
#  11  Fraudulent                        51000 non-null  int64
# ...

# %% [markdown]
# ### Remove Unwanted Data
#
# 1. " a    bc wijasdnfpasdkfwewf        "   -> white spaces
# 2. !@#$%^&*(){}:"<>?,./;'[]     -> special characters /regex(regular expression)
# 3. string functions   -> replace(), strip() => remove white space, LStrip() and RStrip are also there !!! ;)

# %%
df = pd.read_csv("../Dataset/HR_Dataset Refresh.csv")
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 577          Anderson, Carol   10069          0                2         0
# 578         Anderson, Linda    10002          0                0         0
# 579           Andreola, Colby  10194          0                0         0
# 580               Athwal, Sam  10062          0                4         1
# 581          Bachiochi, Linda  10114          0                0         0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    str
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    int64
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    str
# ...

# %%
# have a nice day ;)

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Gender                          0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             386
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_40824\2864691023.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include=['object']).columns
# Index(['Employee_Name', 'Position', 'State', 'DOB', 'Gender', 'MaritalDesc',
#        'CitizenDesc', 'HispanicLatino', 'RaceDesc', 'DateofHire',
#        'DateofTermination', 'TermReason', 'EmploymentStatus', 'Department',
#        'ManagerName', 'RecruitmentSource', 'PerformanceScore',
#        'LastPerformanceReview_Date'],
#       dtype='str')

# %%
columns = ['Position', 'State', 'Gender', 'MaritalDesc',
       'CitizenDesc', 'HispanicLatino', 'RaceDesc', 'TermReason', 'EmploymentStatus', 'Department',
       'ManagerName', 'RecruitmentSource', 'PerformanceScore']

for col in columns:
    unique = df[col].unique()
    print(col)
    print('-' * 20)
    print(unique)
    print("\n")
# Out:
# Position
# --------------------
# <StringArray>
# [     'Production Technician I',                      'Sr. DBA',
#      'Production Technician II',            'Software Engineer',
#                    'IT Support',                 'Data Analyst',
#        'Database Administrator',         'Enterprise Architect',
#                'Sr. Accountant',           'Production Manager',
#                  'Accountant I',           'Area Sales Manager',
#  'Software Engineering Manager',                  'BI Director',
#        'Director of Operations',         'Sr. Network Engineer',
#                 'Sales Manager',                 'BI Developer',
#          'IT Manager - Support',             'Network Engineer',
#                   'IT Director',            'Director of Sales',
#      'Administrative Assistant',              'President & CEO',
#           'Senior BI Developer',      'Shared Services Manager',
#            'IT Manager - Infra',     'Principal Data Architect',
# ...
